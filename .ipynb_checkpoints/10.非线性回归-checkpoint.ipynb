# %%
import numpy as np
import matplotlib.pyplot as plt
from torch import nn,optim
from torch.autograd import Variable
import torch

# %%
# 新加一个维度，变成一个两维的数据
x_data = np.linspace(-2, 2, 200)[:, np.newaxis]
noise = np.random.normal(0, 0.2, x_data.shape)
y_data = np.square(x_data) + noise


plt.scatter(x_data, y_data)
plt.show()

# %%
x_data = x_data.reshape(-1, 1)
# reshape(-1,1) :-1表示自动匹配，1表示一列
# 所以xreshape成了（100行 * 1列）的数据
y_data = y_data.reshape(-1, 1)

# %%
#  把numpy数据变成tensor
x_data = torch.FloatTensor(x_data)
y_data = torch.FloatTensor(y_data)
# 再变ptorch里面的变量
inputs = Variable(x_data)
target = Variable(y_data)
# 为什么：tensor不能反向传播，Variable可以

# %%
# 构建神经网络模型
# 一般把网络中具有可学习参数的层放在__init__()中
class LinearRegression(nn.Module):
    # 定义网络结构
    def __init__(self):
        # 要先初始化nn.Model，父类的初始化，固定的操作
        super(LinearRegression, self).__init__()
        # 1-10-1
        self.fc1 = nn.Linear(1, 10)
        self.tanh = nn.Tanh()
        self.fc2 = nn.Linear(10, 1)

    # 定义网络计算
    def forward(self, x):
        x = self.fc1(x)
        x = self.tanh(x)
        x = self.fc2(x)
        return x

# %%
# 定义模型
model = LinearRegression()
# 定义代价函数
mse_loss = nn.MSELoss()
# 定义优化器
optimizer = optim.SGD(model.parameters(), lr=0.3)

# %%
for name, parameters in model.named_parameters():
    print('name:{},param:{}'.format(name, parameters))
# Out:
# name:fc1.weight,param:Parameter containing:
# tensor([[-0.9589],
#         [-0.8308],
#         [ 0.8192],
#         [-0.3852],
#         [-0.3974],
#         [ 0.2837],
#         [ 0.0648],
#         [-0.1787],
#         [-0.5069],
#         [ 0.1079]], requires_grad=True)
# name:fc1.bias,param:Parameter containing:
# tensor([ 0.7580, -0.6287, -0.8628,  0.7360, -0.0764,  0.4217, -0.1178,  0.4401,
#         -0.0684, -0.8870], requires_grad=True)
# name:fc2.weight,param:Parameter containing:
# tensor([[-0.2661, -0.2598,  0.2603,  0.2357, -0.3121,  0.2805, -0.0171, -0.0782,
#          -0.2314, -0.2009]], requires_grad=True)
# name:fc2.bias,param:Parameter containing:
# tensor([0.2122], requires_grad=True)

# %%
for i in range(2001):
    out = model(inputs)
    # 计算loss
    loss = mse_loss(out, target)
    # 梯度清零(否则梯度会累加)
    optimizer.zero_grad()
    # 计算梯度
    loss.backward()
    # 修改权值
    optimizer.step()

    if i % 200 == 0:
        print(i, loss.item())
# Out:
# 0 2.7240469455718994
# 200 0.35493043065071106
# 400 0.11425992101430893
# 600 0.09261685609817505
# 800 0.07832398265600204
# 1000 0.07150987535715103
# 1200 0.06877115368843079
# 1400 0.06741487234830856
# 1600 0.06649930775165558
# 1800 0.06574226170778275
# 2000 0.0650579184293747

# %%
y_pred = model(inputs)

plt.scatter(x_data, y_data)
plt.plot(x_data, y_pred.data.numpy(), 'r-', lw=3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 plt.scatter(x_data, y_data)
#       4 plt.plot(x_data, y_pred.data.numpy(), 'r-', lw=3)
# ----> 5 plot.show()
#
# NameError: name 'plot' is not defined
